# %% [markdown]
# # **Exemplo**

# %%
nome = "Angelo Ivon"
idade = 15

# %%
print(nome)
# Out:
# Angelo Ivon

# %%
nome
# Out:
# 'Angelo Ivon'

# %%
idade
# Out:
# 15

# %%
print("Seu nome é",nome)
# Out:
# Seu nome é Angelo Ivon

# %%
print("Sua idade é",idade,"Anos de idade")
# Out:
# Sua idade é 15 Anos de idade

# %%
print ("Seu nome é",nome,"\nSua idade é",idade,"anos de idade")
# Out:
# Seu nome é Angelo Ivon
# Sua idade é 15 anos de idade

# %% [markdown]
# # Operadores Aritméticos

# %%
n1 = 7
n2 = 8
n3 = 10

# %%
media=(n1+n2+n3)/3
media
print ("media é de",media)
# Out:
# media é de 8.333333333333334

# %%
round (media,1)
# Out:
# 8.3

# %%
nome=input("Digite seu nome :")
nome
# Out:
# Digite seu nome :angelo
# 'angelo'

# %%
ano_nasc = input("Digite seu ano de nascimento:")
ano_nasc
# Out:
# Digite seu ano de nascimento:0998
# '0998'

# %%
type(ano_nasc)
# Out:
# int

# %%
ano_nasc = int(ano_nasc)

# %%
idade = 2024 - ano_nasc
idade
# Out:
# 1026

# %%
x = 7
#obtendo o resto da divisão de x por 2
divisao_normal = x / 2
resto = x % 2
quociente = x // 2


print("Divisão normal",divisao_normal)
print("Resto - mod %",resto)
print("Quociente - div //",quociente)
# Out:
# Divisão normal 3.5
# Resto - mod % 1
# Quociente - div // 3
